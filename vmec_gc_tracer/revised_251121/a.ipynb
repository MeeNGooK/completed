# %%
import os
import netCDF4 as nc
ncfolder=os.path.join(os.getcwd(),'nc')
filename='wout_pwO_nfp2_A6.nc'
filepath=os.path.join(ncfolder,filename)
f=nc.Dataset(filepath, 'r')

# %%
f.variables['phi'][:].data[257]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 f.variables['phi'][:].data[257]
#
# IndexError: index 257 is out of bounds for axis 0 with size 257
