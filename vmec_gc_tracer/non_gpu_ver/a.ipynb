# %%
import os
import netCDF4 as nc
filename='wout_iota0_42.nc'
filepath=os.path.join(os.getcwd(),filename)
f=nc.Dataset(filepath, 'r')

# %%
f.variables['phi'][:].data[111]
# Out:
# 0.17267491039800156
